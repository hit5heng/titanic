# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras import layers

# %%
tf.__version__
# Out:
# '1.12.0'

# %%
data1 = pd.read_csv("./data1.csv")

# %%
data1
# Out:
#      Survived  Sex        Age  SibSp  Parch      Fare  Cabin  p1  p2  p3  e1  \
# 0           0    1  22.000000      1      0    7.2500     -1   0   0   1   1
# 1           1    0  38.000000      1      0   71.2833      0   1   0   0   0
# 2           1    0  26.000000      0      0    7.9250     -1   0   0   1   1
# 3           1    0  35.000000      1      0   53.1000      1   1   0   0   1
# 4           0    1  35.000000      0      0    8.0500     -1   0   0   1   1
# 5           0    1  29.699118      0      0    8.4583     -1   0   0   1   0
# 6           0    1  54.000000      0      0   51.8625      2   1   0   0   1
# 7           0    1   2.000000      3      1   21.0750     -1   0   0   1   1
# 8           1    0  27.000000      0      2   11.1333     -1   0   0   1   1
# 9           1    0  14.000000      1      0   30.0708     -1   0   1   0   0
# 10          1    0   4.000000      1      1   16.7000      3   0   0   1   1
# ...

# %%
data1_train = data1[['Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Cabin','p1', 'p2', 'p3', 'e1', 'e2', 'e3']]

data1_target = data1['Survived'].values.reshape(len(data1),1)

# %%
np.shape(data1_train), np.shape(data1_target)
# Out:
# ((891, 12), (891, 1))

# %%
x = tf.placeholder('float', shape=[None, 12])
y = tf.placeholder('float', shape=[None, 1])

# %%
weight = tf.Variable(tf.random_normal([12,1]))
bias = tf.Variable(tf.random_normal([1]))
output = tf.matmul(x,weight) + bias  #矩阵乘法
pred = tf.cast(tf.sigmoid(output)>0.5, tf.float32)  #得到布尔值，转换为0，1

# %%
loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(labels = y, logits = output))

# %%
train_step = tf.train.GradientDescentOptimizer(0.0003).minimize(loss)

# %%
accuracy = tf.reduce_mean(tf.cast(tf.equal(pred, y), tf.float32))

# %%
test_label = pd.read_csv('./data/gender_submission.csv')
test_lable = np.reshape(test_label.Survived.values.astype(np.float32),(418,1))

# %%
sess = tf.Session()
sess.run =(tf.global_variables_initializer())
loss_train = []
train_acc = []
test_acc = []

# %%
for i in range(25000):
    index = np.random.permutation(len(data_target))  # luan xu
